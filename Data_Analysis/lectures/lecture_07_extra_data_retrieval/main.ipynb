# %% [markdown]
# # Регулярные выражения

# %% [markdown]
# <img width='450px' src="images/use-regex.jpg"></img>

# %% [markdown]
# Некоторые люди, когда сталкиваются с проблемой, думают:
#
#     «Я знаю, я решу её с помощью регулярных выражений.»
#
# Теперь у них **ДВЕ** проблемы.

# %% [markdown]
# ## Что почитать?
#
# 1. Хороший [«быстрый старт»](https://tproger.ru/translations/regular-expression-python/) с задачками от TProger.
# 2. Отличный [туториал](https://habr.com/post/349860/) с задачками на Хабре.
# 3. [Документация](https://docs.python.org/3/library/re.html) к стандартной библиотеке.

# %%
import re

# %% [markdown]
# # Структура URL

# %% [markdown]
# http://www.example.com:80/path/to/myfile.html?key1=value1&key2=value2#SomewhereInTheDocument
#
# <img width='480px' src="https://mdn.mozillademos.org/files/8013/mdn-url-protocol@x2.png"></img>
# <img width='480px' src="https://mdn.mozillademos.org/files/8015/mdn-url-protocol@x2.png"></img>
# <img width='480px' src="https://mdn.mozillademos.org/files/8017/mdn-url-protocol@x2.png"></img>
# <img width='480px' src="https://mdn.mozillademos.org/files/8019/mdn-url-protocol@x2.png"></img>
# <img width='480px' src="https://mdn.mozillademos.org/files/8021/mdn-url-protocol@x2.png"></img>
# <img width='480px' src="https://mdn.mozillademos.org/files/8023/mdn-url-protocol@x2.png"></img>
#
# https://developer.mozilla.org/ru/docs/Learn/Understanding_URLs

# %% [markdown]
# # Типы HTTP запросов и ответов

# %% [markdown]
# <img width='500px' src="images/swagger-petstore-endpoint-methods.png"></img>

# %% [markdown]
# <img width='800px' src="images/responses.jpg"></img>

# %% [markdown]
# Табличка с типами ответов: [клац раз](https://www.steveschoger.com/status-code-poster/img/status-code.png) и [клац два](https://ru.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D0%BA%D0%BE%D0%B4%D0%BE%D0%B2_%D1%81%D0%BE%D1%81%D1%82%D0%BE%D1%8F%D0%BD%D0%B8%D1%8F_HTTP).

# %% [markdown]
# # Работа с JSON

# %%
import requests

# %% [markdown]
# [Документация](http://docs.python-requests.org/) по библиотеке requests.

# %%
import json

# %% [markdown]
# Prepare token: https://developer.spotify.com/console/get-track/?id=3n3Ppam7vgaVa1iaRUc9Lp

# %%
with open('spotify-api-token.key', mode='r') as f_key:
    spotify_api_token = f_key.readline()
    

class SpotifyAPI:    
    def __init__(self, token):
        self._token = token

    def get_track_info(self, track_id, market='US'):
        # посылаем get запрос, указываем аргументы и заголовки
        ret = requests.get("https://api.spotify.com/v1/tracks/{}".format(track_id),
                           params={'market': market,},
                           headers={'Authorization': f'Bearer {self._token}'})
        return ret


spotify = SpotifyAPI(spotify_api_token)
r = spotify.get_track_info('3n3Ppam7vgaVa1iaRUc9Lp')
r.status_code
# Out:
# 200

# %%
r.headers
# Out:
# {'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=7200', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Headers': 'Accept, Authorization, Origin, Content-Type, Retry-After', 'Access-Control-Allow-Methods': 'GET, POST, OPTIONS, PUT, DELETE, PATCH', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Max-Age': '604800', 'Content-Encoding': 'gzip', 'Date': 'Fri, 29 Mar 2019 09:26:26 GMT', 'Via': '1.1 google', 'Alt-Svc': 'clear', 'Transfer-Encoding': 'chunked'}

# %%
print(r.text)
# Out:
# {
#   "album" : {
#     "album_type" : "album",
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu"
#       },
#       "href" : "https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu",
#       "id" : "0C0XlULifJtAgn6ZNCW2eu",
#       "name" : "The Killers",
#       "type" : "artist",
#       "uri" : "spotify:artist:0C0XlULifJtAgn6ZNCW2eu"
#     } ],
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/album/4OHNH3sDzIxnmUADXzv2kT"
#     },
#     "href" : "https://api.spotify.com/v1/albums/4OHNH3sDzIxnmUADXzv2kT",
#     "id" : "4OHNH3sDzIxnmUADXzv2kT",
#     "images" : [ {
#       "height" : 640,
#       "url" : "https://i.scdn.co/image/ac68a9e4a867ec3ce8249cd90a2d7c73755fb487",
#       "width" : 629
#     }, {
#       "height" : 300,
#       "url" : "https://i.scdn.co/image/d0186ad64df7d6fc5f65c20c7d16f4279ffeb815",
#       "width" : 295
#     }, {
#       "height" : 64,
#       "url" : "https://i.scdn.co/image/7c3ec33d478f5f517eeb5339c2f75f150e4d601e",
#       "width" : 63
#     } ],
#     "name" : "Hot Fuss",
#     "release_date" : "2004",
#     "release_date_precision" : "year",
#     "total_tracks" : 14,
#     "type" : "album",
#     "uri" : "spotify:album:4OHNH3sDzIxnmUADXzv2kT"
#   },
#   "artists" : [ {
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu"
#     },
#     "href" : "https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu",
#     "id" : "0C0XlULifJtAgn6ZNCW2eu",
#     "name" : "The Killers",
#     "type" : "artist",
#     "uri" : "spotify:artist:0C0XlULifJtAgn6ZNCW2eu"
#   } ],
#   "disc_number" : 1,
#   "duration_ms" : 222586,
#   "explicit" : false,
#   "external_ids" : {
#     "isrc" : "USIR20400274"
#   },
#   "external_urls" : {
#     "spotify" : "https://open.spotify.com/track/7oK9VyNzrYvRFo7nQEYkWN"
#   },
#   "href" : "https://api.spotify.com/v1/tracks/7oK9VyNzrYvRFo7nQEYkWN",
#   "id" : "7oK9VyNzrYvRFo7nQEYkWN",
#   "is_local" : false,
#   "is_playable" : true,
#   "linked_from" : {
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/3n3Ppam7vgaVa1iaRUc9Lp"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/3n3Ppam7vgaVa1iaRUc9Lp",
#     "id" : "3n3Ppam7vgaVa1iaRUc9Lp",
#     "type" : "track",
#     "uri" : "spotify:track:3n3Ppam7vgaVa1iaRUc9Lp"
#   },
#   "name" : "Mr. Brightside",
#   "popularity" : 80,
#   "preview_url" : null,
#   "track_number" : 2,
#   "type" : "track",
#   "uri" : "spotify:track:7oK9VyNzrYvRFo7nQEYkWN"
# }

# %%
r.content
# Out:
# b'{\n  "album" : {\n    "album_type" : "album",\n    "artists" : [ {\n      "external_urls" : {\n        "spotify" : "https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu"\n      },\n      "href" : "https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu",\n      "id" : "0C0XlULifJtAgn6ZNCW2eu",\n      "name" : "The Killers",\n      "type" : "artist",\n      "uri" : "spotify:artist:0C0XlULifJtAgn6ZNCW2eu"\n    } ],\n    "external_urls" : {\n      "spotify" : "https://open.spotify.com/album/4OHNH3sDzIxnmUADXzv2kT"\n    },\n    "href" : "https://api.spotify.com/v1/albums/4OHNH3sDzIxnmUADXzv2kT",\n    "id" : "4OHNH3sDzIxnmUADXzv2kT",\n    "images" : [ {\n      "height" : 640,\n      "url" : "https://i.scdn.co/image/ac68a9e4a867ec3ce8249cd90a2d7c73755fb487",\n      "width" : 629\n    }, {\n      "height" : 300,\n      "url" : "https://i.scdn.co/image/d0186ad64df7d6fc5f65c20c7d16f4279ffeb815",\n      "width" : 295\n    }, {\n      "height" : 64,\n      "url" : "https://i.scdn.co/image/7c3ec33d478f5f517eeb5339c2f75f150e4d601e",\n      "width" : 63\n    } ],\n    "name" : "Hot Fuss",\n    "release_date" : "2004",\n    "release_date_precision" : "year",\n    "total_tracks" : 14,\n    "type" : "album",\n    "uri" : "spotify:album:4OHNH3sDzIxnmUADXzv2kT"\n  },\n  "artists" : [ {\n    "external_urls" : {\n      "spotify" : "https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu"\n    },\n    "href" : "https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu",\n    "id" : "0C0XlULifJtAgn6ZNCW2eu",\n    "name" : "The Killers",\n    "type" : "artist",\n    "uri" : "spotify:artist:0C0XlULifJtAgn6ZNCW2eu"\n  } ],\n  "disc_number" : 1,\n  "duration_ms" : 222586,\n  "explicit" : false,\n  "external_ids" : {\n    "isrc" : "USIR20400274"\n  },\n  "external_urls" : {\n    "spotify" : "https://open.spotify.com/track/7oK9VyNzrYvRFo7nQEYkWN"\n  },\n  "href" : "https://api.spotify.com/v1/tracks/7oK9VyNzrYvRFo7nQEYkWN",\n  "id" : "7oK9VyNzrYvRFo7nQEYkWN",\n  "is_local" : false,\n  "is_playable" : true,\n  "linked_from" : {\n    "external_urls" : {\n      "spotify" : "https://open.spotify.com/track/3n3Ppam7vgaVa1iaRUc9Lp"\n    },\n    "href" : "https://api.spotify.com/v1/tracks/3n3Ppam7vgaVa1iaRUc9Lp",\n    "id" : "3n3Ppam7vgaVa1iaRUc9Lp",\n    "type" : "track",\n    "uri" : "spotify:track:3n3Ppam7vgaVa1iaRUc9Lp"\n  },\n  "name" : "Mr. Brightside",\n  "popularity" : 80,\n  "preview_url" : null,\n  "track_number" : 2,\n  "type" : "track",\n  "uri" : "spotify:track:7oK9VyNzrYvRFo7nQEYkWN"\n}'

# %%
answer = json.loads(r.content)
type(answer)
# Out:
# dict

# %%
answer = r.json()
type(answer)
# Out:
# dict

# %%
answer_cut = {
    'artist':   answer['artists'][0]['name'],
    'name':     answer['name'],
    'duration': answer['duration_ms'] / 1000.0,
    'href':     answer['href'],
    'id':       answer['id'],
}
answer_cut
# Out:
# {'artist': 'The Killers',
#  'name': 'Mr. Brightside',
#  'duration': 222.586,
#  'href': 'https://api.spotify.com/v1/tracks/7oK9VyNzrYvRFo7nQEYkWN',
#  'id': '7oK9VyNzrYvRFo7nQEYkWN'}

# %%
# компактно сериализуем json в строку
json.dumps(answer_cut, separators=(',', ':'))
# Out:
# '{"artist":"The Killers","name":"Mr. Brightside","duration":222.586,"href":"https://api.spotify.com/v1/tracks/7oK9VyNzrYvRFo7nQEYkWN","id":"7oK9VyNzrYvRFo7nQEYkWN"}'

# %%
# pretty print для json
print(json.dumps(answer_cut, indent=4, sort_keys=True))
# Out:
# {
#     "artist": "The Killers",
#     "duration": 222.586,
#     "href": "https://api.spotify.com/v1/tracks/7oK9VyNzrYvRFo7nQEYkWN",
#     "id": "7oK9VyNzrYvRFo7nQEYkWN",
#     "name": "Mr. Brightside"
# }

# %%
with open('/tmp/answer_cut.json', mode='w') as f_json:
    json.dump(answer_cut, f_json)

# %%
# !cat /tmp/answer_cut.json
# Out:
# {"artist": "The Killers", "name": "Mr. Brightside", "duration": 222.586, "href": "https://api.spotify.com/v1/tracks/7oK9VyNzrYvRFo7nQEYkWN", "id": "7oK9VyNzrYvRFo7nQEYkWN"}

# %%
# !cat /tmp/answer_cut.json | python -m json.tool
# Out:
# {
#     "artist": "The Killers",
#     "name": "Mr. Brightside",
#     "duration": 222.586,
#     "href": "https://api.spotify.com/v1/tracks/7oK9VyNzrYvRFo7nQEYkWN",
#     "id": "7oK9VyNzrYvRFo7nQEYkWN"
# }

# %%
with open('/tmp/answer_cut.json', mode='r') as f_json:
    answer_cut = json.load(f_json)
answer_cut
# Out:
# {'artist': 'The Killers',
#  'name': 'Mr. Brightside',
#  'duration': 222.586,
#  'href': 'https://api.spotify.com/v1/tracks/7oK9VyNzrYvRFo7nQEYkWN',
#  'id': '7oK9VyNzrYvRFo7nQEYkWN'}

# %% [markdown]
# ## А можно ли как-то ускорить процесс обкачки?

# %% [markdown]
# Какая разница между процессом и потоками (threads)?

# %% [markdown]
# <img width='600px' src="https://joearms.github.io/images/con_and_par.jpg"></img>

# %% [markdown]
# Глобальная блокировка интерпретатора ( global interpreter lock , **GIL** ) Python. Если два или более потока попытаются манипулировать одним и тем же объектом в одно и то же время, то неизбежно возникнут проблемы. Глобальная блокировка интерпретатора исправляет это. В любой момент времени действия может выполнять только один поток. Python автоматически переключается между потоками, когда в этом возникает необходимость.
#
# GIL в Python реализован как обычный lock.

# %% [markdown]
# Скачивание данных через библиотеку requsets – I/O операция, поэтому большую часть времени процессор не выполняет никаких задач, потому что ждёт, пока данные придут по сети.

# %%
from tqdm import tqdm

# %%
# %%time

n_post_first, n_post_final = 349000, 349200

r = [requests.get('https://habrahabr.ru/post/{}/'.format(post_id))
     for post_id in tqdm(range(n_post_first, n_post_final, 2))]
# Out:
# 100%|██████████| 100/100 [00:56<00:00,  1.78it/s]
# CPU times: user 4.67 s, sys: 303 ms, total: 4.97 s
# Wall time: 56.2 s

# %%
from multiprocessing.dummy import Pool as ThreadPool

# %%
# %%time

n_post_first, n_post_final = 349000, 349200

def get_habr_post(post_id):
    return requests.get('https://habrahabr.ru/post/{}/'.format(post_id))

pool = ThreadPool(10)
r = pool.map(get_habr_post, range(n_post_first, n_post_final, 2))
pool.close()
pool.join()
# Out:
# CPU times: user 3.31 s, sys: 321 ms, total: 3.64 s
# Wall time: 3.11 s

# %%
from multiprocessing import Pool

# %%
# %%time

n_post_first, n_post_final = 349000, 349200

def get_habr_post(post_id):
    return requests.get('https://habrahabr.ru/post/{}/'.format(post_id))

pool = Pool(processes=10)
r = pool.map(get_habr_post, range(n_post_first, n_post_final, 2))
pool.close()
pool.join()
# Out:
# CPU times: user 32.3 ms, sys: 77.7 ms, total: 110 ms
# Wall time: 2.73 s

# %% [markdown]
# # Парсинг HTML-страничек

# %% [markdown]
# <img width='800px' src="https://q-bit.biz/uploads/article/Tegs_1539003896.png"></img>

# %% [markdown]
# ## robots.txt
#
# 1. Валидаторы:
#     * https://webmaster.yandex.ru/tools/robotstxt/
#     * https://technicalseo.com/seo-tools/robots-txt/
# 2. Все о robots.txt:
#     * https://help.mail.ru/webmaster/indexing/robots.txt
#     * https://yandex.ru/support/webmaster/controlling-robot/

# %% [markdown]
# ## HTMLParser

# %% [markdown]
# https://www.kinopoisk.ru/film/garri-potter-i-taynaya-komnata-2002-688/

# %%
from html.parser import HTMLParser

# %%
film_url = 'https://www.kinopoisk.ru/film/garri-potter-i-taynaya-komnata-2002-688/'
film_html = requests.get(film_url).text

# %%
class KinoPoiskParser(HTMLParser):
    """
    Парсер страниц КиноПоиска с фильмами.

    Извлекает следующую информацию:
        1. название;
        2. оригинальное название;
        3. страны производители;
        4. длительность;
        5. описание;
        6. рейтинг.
    """

    def __init__(self):
        super().__init__()
        self.film_info = dict()
        self.status = None
        
    def handle_starttag(self, tag, attrs):
        attrs = dict(attrs)
        self.status = None
        
        # HTML Parser не умеет сплитить значения атрибутов по пробелу
        if 'class' in attrs:
            attrs['class'] = attrs['class'].split()
        else:
            attrs['class'] = []
        
        if tag == 'h1' and 'moviename-big' in attrs['class']:
            # 1. Название фильма
            self.status = 'title'
        elif tag == 'span':
            if attrs.get('itemprop', '') == 'alternativeHeadline':
                # 2. Оригинальное название фильма
                self.status = 'title-original'
            elif 'rating_ball' in attrs['class']:
                # 6. Рейтинг фильма
                self.status = 'rating'
        elif tag == 'div':
            if 'flag' in attrs['class']:
                # 3. Страны производители
                if 'countries' not in self.film_info:
                    self.film_info['countries'] = []
                
                country = attrs.get('title')
                if country:
                    self.film_info['countries'].append(country)
            elif attrs.get('itemprop') == 'description':
                # 5. Описание фильма
                self.status = 'description'
        elif tag == 'td' and 'time' in attrs['class'] and \
                attrs.get('id', '') == 'runtime':
            # 4. Длительность фильма
            self.status = 'time'
            
    def handle_data(self, data):
        data = data.strip()
        
        if not data:
            return
        
        if self.status is not None:
            if self.status == 'rating':
                # приводим рейтинг к float
                data = float(data)
            elif self.status == 'time':
                # форматируем дату
                data = re.search('\d+', data)
                data = int(data.group(0))
                data = "{:02}:{}".format(data // 60, data % 60)
            else:
                # в остальных случаях убираем лишние пробелы
                data = re.sub('\s+', ' ', data)
            self.film_info[self.status] = data 
            
    def clear():
        # очищаем информацию о фильме, перед обработкой
        # новой страницы
        self.film_info = {}

# %%
parser = KinoPoiskParser()

# %%
parser.feed(film_html)
parser.film_info
# Out:
# {'title': 'Гарри Поттер и Тайная комната',
#  'title-original': 'Harry Potter and the Chamber of Secrets',
#  'countries': ['Великобритания', 'США', 'Германия'],
#  'time': '02:41',
#  'description': 'Гарри Поттер переходит на второй курс Школы чародейства и волшебства Хогвартс. Эльф Добби предупреждает Гарри об опасности, которая поджидает его там, и просит больше не возвращаться в школу.',
#  'rating': 8.031}

# %% [markdown]
# ## Beautiful Soup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# <img width = '330px' src="images/bsoup.jpg">

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(film_html, 'html.parser')

# %% [markdown]
# ### Соберем основную информацию о фильме

# %%
film_info = {
    'title': soup.find('h1', class_='moviename-big').text,
    'title-original': soup.find('span', itemprop='alternativeHeadline').text,
    'countries': list(map(lambda e: e.attrs['title'], soup.find_all('div', class_='flag'))),
    'time': re.search('\d\d:\d\d', soup.find('td', class_='time').text).group(0),
    'rating': float(soup.select_one('.rating_ball').text) # поддержка CSS-селекторов
}

film_info
# Out:
# {'title': 'Гарри Поттер и Тайная комната',
#  'title-original': 'Harry Potter and the Chamber of Secrets',
#  'countries': ['Великобритания', 'США', 'Германия'],
#  'time': '02:41',
#  'rating': 8.031}

# %%
desc = soup.find('div', itemprop='description')
desc
# Out:
# <div class="brand_words film-synopsys" itemprop="description">Гарри Поттер переходит на второй курс Школы чародейства и волшебства Хогвартс. Эльф Добби предупреждает Гарри об опасности, которая поджидает его там, и просит больше не возвращаться в школу.<br/><br/>Юный волшебник не следует совету эльфа и становится свидетелем таинственных событий, разворачивающихся в Хогвартсе. Вскоре Гарри и его друзья узнают о существовании Тайной Комнаты и сталкиваются с новыми приключениями, пытаясь победить темные силы.</div>

# %%
desc.text
# Out:
# 'Гарри Поттер переходит на\xa0второй курс Школы чародейства и\xa0волшебства Хогвартс. Эльф Добби предупреждает Гарри об\xa0опасности, которая поджидает его\xa0там, и\xa0просит больше не\xa0возвращаться в\xa0школу.Юный волшебник не\xa0следует совету эльфа и\xa0становится свидетелем таинственных событий, разворачивающихся в\xa0Хогвартсе. Вскоре Гарри и\xa0его друзья узнают о\xa0существовании Тайной Комнаты и\xa0сталкиваются с\xa0новыми приключениями, пытаясь победить темные силы.'

# %%
for br in desc.find_all("br"):
    br.replace_with("\n")
desc
# Out:
# <div class="brand_words film-synopsys" itemprop="description">Гарри Поттер переходит на второй курс Школы чародейства и волшебства Хогвартс. Эльф Добби предупреждает Гарри об опасности, которая поджидает его там, и просит больше не возвращаться в школу.
#
# Юный волшебник не следует совету эльфа и становится свидетелем таинственных событий, разворачивающихся в Хогвартсе. Вскоре Гарри и его друзья узнают о существовании Тайной Комнаты и сталкиваются с новыми приключениями, пытаясь победить темные силы.</div>

# %%
film_info['description'] = re.sub('\s+', ' ', desc.text)
film_info
# Out:
# {'title': 'Гарри Поттер и Тайная комната',
#  'title-original': 'Harry Potter and the Chamber of Secrets',
#  'countries': ['Великобритания', 'США', 'Германия'],
#  'time': '02:41',
#  'rating': 8.031,
#  'description': 'Гарри Поттер переходит на второй курс Школы чародейства и волшебства Хогвартс. Эльф Добби предупреждает Гарри об опасности, которая поджидает его там, и просит больше не возвращаться в школу. Юный волшебник не следует совету эльфа и становится свидетелем таинственных событий, разворачивающихся в Хогвартсе. Вскоре Гарри и его друзья узнают о существовании Тайной Комнаты и сталкиваются с новыми приключениями, пытаясь победить темные силы.'}

# %% [markdown]
# ### Извлечем таблицу

# %%
table = soup.find('table', class_='info')
rows = table.find_all('tr')

# %%
data = [list(map(lambda x: x.text, row.find_all('td'))) for row in rows]
data
# Out:
# [['год', '\n2002\n'],
#  ['страна', '\nВеликобритания, США, Германия\n'],
#  ['слоган', '«Зло вернулось в Хогвартс»'],
#  ['режиссер', 'Крис Коламбус'],
#  ['сценарий', 'Стивен Кловз, Дж.К. Роулинг'],
#  ['продюсер', 'Дэвид Хейман, Майкл Барнатан, Дэвид Баррон, ...'],
#  ['оператор', 'Роджер Прэтт'],
#  ['композитор', 'Джон Уильямс'],
#  ['художник', 'Стюарт Крэйг, Эндрю Эклэнд-Сноу, Марк Бартоломью, ...'],
#  ['монтаж', 'Питер Хонесс'],
#  ['жанр', '\nфэнтези, детектив, приключения, семейный, ...\nслова\n'],
#  ['бюджет', '\n$100\xa0000\xa0000\n'],
#  ['маркетинг', '\n$50\xa0000\xa0000\n'],
#  ['сборы в США',
#   '\n\n$261\xa0988\xa0482\n\n\n var is_usa_box_popup = true; \n'],
#  ['сборы в мире',
#   '\n\n+\xa0$616\xa0991\xa0152\xa0=\xa0$878\xa0979\xa0634\nсборы\n\n var is_world_box_popup = false; \n'],
#  ['сборы в России',
#   '\n\n$8\xa0000\xa0000\n\n\n var is_rus_box_popup = true; \n'],
#  ['зрители',
#   '\n\xa0\xa045.1 млн,\xa0\xa0\xa0\xa0\xa0\xa013.9 млн,\xa0\xa0\xa0\xa0\xa0\xa012.2 млн, ...\n'],
#  ['премьера (мир)', '\n\n\n3 ноября 2002, ...\n\n\n\n'],
#  ['премьера (РФ)',
#   '\n\n\n26 декабря 2002,\n                       «Каро-Премьер»\n                       \n\n\n'],
#  ['релиз на DVD',
#   '\n\n\n\n22\xa0апреля\xa02003,\n                            «Premier Digital»,\n                            ...\n\n'],
#  ['релиз на Blu-ray',
#   '\n\n\n\n20\xa0января\xa02009,\n                            «Юниверсал Пикчерс Рус»,\n                            ...\n\n'],
#  ['возраст', '\n\nзрителям, достигшим 12 лет\n'],
#  ['рейтинг MPAA',
#   '\n\n\n                            рекомендуется присутствие родителей\n                            \n                        \n'],
#  ['время', '161 мин. / 02:41']]

# %%
data = [list(map(lambda x: re.sub("\s+", ' ', x.text.strip()), row.find_all('td')))
        for row in rows]
data
# Out:
# [['год', '2002'],
#  ['страна', 'Великобритания, США, Германия'],
#  ['слоган', '«Зло вернулось в Хогвартс»'],
#  ['режиссер', 'Крис Коламбус'],
#  ['сценарий', 'Стивен Кловз, Дж.К. Роулинг'],
#  ['продюсер', 'Дэвид Хейман, Майкл Барнатан, Дэвид Баррон, ...'],
#  ['оператор', 'Роджер Прэтт'],
#  ['композитор', 'Джон Уильямс'],
#  ['художник', 'Стюарт Крэйг, Эндрю Эклэнд-Сноу, Марк Бартоломью, ...'],
#  ['монтаж', 'Питер Хонесс'],
#  ['жанр', 'фэнтези, детектив, приключения, семейный, ... слова'],
#  ['бюджет', '$100 000 000'],
#  ['маркетинг', '$50 000 000'],
#  ['сборы в США', '$261 988 482 var is_usa_box_popup = true;'],
#  ['сборы в мире',
#   '+ $616 991 152 = $878 979 634 сборы var is_world_box_popup = false;'],
#  ['сборы в России', '$8 000 000 var is_rus_box_popup = true;'],
#  ['зрители', '45.1 млн, 13.9 млн, 12.2 млн, ...'],
#  ['премьера (мир)', '3 ноября 2002, ...'],
#  ['премьера (РФ)', '26 декабря 2002, «Каро-Премьер»'],
#  ['релиз на DVD', '22 апреля 2003, «Premier Digital», ...'],
#  ['релиз на Blu-ray', '20 января 2009, «Юниверсал Пикчерс Рус», ...'],
#  ['возраст', 'зрителям, достигшим 12 лет'],
#  ['рейтинг MPAA', 'рекомендуется присутствие родителей'],
#  ['время', '161 мин. / 02:41']]

# %%
for row in rows:
    for script in row.find_all("script"):
        script.replace_with('')
        
data = [list(map(lambda x: re.sub("\s+", ' ', x.text.strip()), row.find_all('td')))
        for row in rows]
data
# Out:
# [['год', '2002'],
#  ['страна', 'Великобритания, США, Германия'],
#  ['слоган', '«Зло вернулось в Хогвартс»'],
#  ['режиссер', 'Крис Коламбус'],
#  ['сценарий', 'Стивен Кловз, Дж.К. Роулинг'],
#  ['продюсер', 'Дэвид Хейман, Майкл Барнатан, Дэвид Баррон, ...'],
#  ['оператор', 'Роджер Прэтт'],
#  ['композитор', 'Джон Уильямс'],
#  ['художник', 'Стюарт Крэйг, Эндрю Эклэнд-Сноу, Марк Бартоломью, ...'],
#  ['монтаж', 'Питер Хонесс'],
#  ['жанр', 'фэнтези, детектив, приключения, семейный, ... слова'],
#  ['бюджет', '$100 000 000'],
#  ['маркетинг', '$50 000 000'],
#  ['сборы в США', '$261 988 482'],
#  ['сборы в мире', '+ $616 991 152 = $878 979 634 сборы'],
#  ['сборы в России', '$8 000 000'],
#  ['зрители', '45.1 млн, 13.9 млн, 12.2 млн, ...'],
#  ['премьера (мир)', '3 ноября 2002, ...'],
#  ['премьера (РФ)', '26 декабря 2002, «Каро-Премьер»'],
#  ['релиз на DVD', '22 апреля 2003, «Premier Digital», ...'],
#  ['релиз на Blu-ray', '20 января 2009, «Юниверсал Пикчерс Рус», ...'],
#  ['возраст', 'зрителям, достигшим 12 лет'],
#  ['рейтинг MPAA', 'рекомендуется присутствие родителей'],
#  ['время', '161 мин. / 02:41']]

# %%
import pandas as pd

# %%
# Внимание! Из таблицы все равно придется убрать скрипты

df = pd.read_html(str(table))[0]
df
# Out:
#                    0                                                  1
# 0                год                                               2002
# 1             страна                      Великобритания, США, Германия
# 2             слоган                         «Зло вернулось в Хогвартс»
# 3           режиссер                                      Крис Коламбус
# 4           сценарий                        Стивен Кловз, Дж.К. Роулинг
# 5           продюсер    Дэвид Хейман, Майкл Барнатан, Дэвид Баррон, ...
# 6           оператор                                       Роджер Прэтт
# 7         композитор                                       Джон Уильямс
# 8           художник  Стюарт Крэйг, Эндрю Эклэнд-Сноу, Марк Бартолом...
# 9             монтаж                                       Питер Хонесс
# 10              жанр  фэнтези, детектив, приключения, семейный, ... ...
# 11            бюджет                                       $100 000 000
# 12         маркетинг                                        $50 000 000
# 13       сборы в США                                       $261 988 482
# 14      сборы в мире                + $616 991 152 = $878 979 634 сборы
# 15    сборы в России                                         $8 000 000
# 16           зрители                  45.1 млн, 13.9 млн, 12.2 млн, ...
# 17    премьера (мир)                                 3 ноября 2002, ...
# 18     премьера (РФ)                   26 декабря 2002,  «Каро-Премьер»
# 19      релиз на DVD           22 апреля 2003,  «Premier Digital»,  ...
# 20  релиз на Blu-ray     20 января 2009,  «Юниверсал Пикчерс Рус»,  ...
# 21           возраст                         зрителям, достигшим 12 лет
# 22      рейтинг MPAA                рекомендуется присутствие родителей
# 23             время                                   161 мин. / 02:41

# %% [markdown]
# ### Пройдемся по спискам

# %%
actors, actors_dub = soup.find('div', id='actorList').find_all('ul')

# %%
[row.text for row in actors.children if row.text != '...']
# Out:
# ['Дэниэл Рэдклифф',
#  'Руперт Гринт',
#  'Эмма Уотсон',
#  'Том Фелтон',
#  'Кеннет Брана',
#  'Бонни Райт',
#  'Алан Рикман',
#  'Ричард Харрис',
#  'Мэгги Смит',
#  'Робби Колтрейн']

# %%
[row.text for row in actors_dub.children if row.text != '...']
# Out:
# ['Николай Быстров',
#  'Ольга Сирина',
#  'Лина Иванова',
#  'Александр Скрывля',
#  'Вадим Андреев']

# %% [markdown]
# ### Обкачаем картинки

# %%
film_photos_html = requests.get(
    'https://www.kinopoisk.ru/film/garri-potter-i-taynaya-komnata-2002-688/stills/').content

# %%
soup = BeautifulSoup(film_photos_html, 'html.parser')

# %%
list(map(lambda s: s.attrs['src'], soup.find('table', class_='fotos').findAll("img")))[:10]
# Out:
# ['https://st.kp.yandex.net/images/kadr/sm_2094224.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2005184.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2005183.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2005182.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2005181.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_1558456.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_1558455.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_1558454.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_1558453.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_1558452.jpg']

# %% [markdown]
# ## Заголовки

# %% [markdown]
# https://www.dafont.com/

# %%
r = requests.get('https://www.dafont.com/')
len(r.text)
# Out:
# 0

# %% [markdown]
# https://pypi.org/project/fake-useragent/

# %%
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) ' +
                         'AppleWebKit/537.36 (KHTML, like Gecko) ' +
                         'Chrome/42.0.2311.90 Safari/537.36'}

r = requests.get('https://www.dafont.com/', headers=headers)
len(r.text)
# Out:
# 19824

# %% [markdown]
# ## Cookie

# %% [markdown]
# Cookie (куки) — это небольшие текстовые файлы, в которые браузер записывает данные с посещенных вами сайтов. Файлы cookie позволяют сайтам «запоминать» своих посетителей, например, чтобы каждый раз не переспрашивать их логин и пароль.
#
# chrome://settings/cookies/detail?site=sphere.mail.ru (sessionid_gtp)

# %%
r = requests.get('https://sphere.mail.ru/people/', params={'q': 'BD-11'})
r.ok
# Out:
# True

# %%
soup = BeautifulSoup(r.content, 'html.parser')

table = soup.find('div', class_='people-list')
table is not None
# Out:
# False

# %%
with open('sphere-cookies.json', mode='r') as f_cookies:
    cookies = json.load(f_cookies)
    
r = requests.get('https://sphere.mail.ru/people/', params={'q': 'BD-11'}, cookies=cookies)
r.ok
# Out:
# True

# %%
soup = BeautifulSoup(r.content, 'html.parser')

table = soup.find('div', class_='people-list')
table is not None
# Out:
# True

# %%
from urllib.parse import urlparse

# %%
rows = table.find('table', class_='table-users').find('tbody').find_all('tr')

users = [{'name': row.find('p', class_='realname').text,
          'nick': urlparse(row.find('p', class_='username').find('a').attrs['href']).\
              path.split('/')[2],
          'type': row.find('span', class_='user-group').text,
          'power': row.find('td', class_='cell-skill').text,
          'rating': row.find('td', class_='cell-rating').text.strip()}
         for row in rows]

df = pd.DataFrame(users)
df.head(10)
# Out:
#                   name            nick power rating     type
# 0        Дмитрий Малов         d.malov  0,00   1.93  Студент
# 1       Кирилл Бухтеев       k.buhteev  0,00   1.51  Студент
# 2  Дмитрий Мержвинский  d.merzhvinskij  0,00   1.51  Студент
# 3    Георгий Броницкий    g.bronitskij  0,00   1.51  Студент
# 4       Василий Висков        v.viskov  0,00   1.51  Студент
# 5        Олег Шевченко   ol.shevchenko  0,00   1.51  Студент
# 6      Сергей Стариков      s.starikov  0,00   1.09  Студент
# 7      Георгий Русанов       r.georgij  0,00   1.09  Студент
# 8       Елисей Питанов      el.pitanov  0,00   1.09  Студент
# 9      Андрей Тюняткин    a.tyunyatkin  0,00   1.09  Студент

# %% [markdown]
# ## Proxy

# %%
r = requests.get('https://yandex.ru/internet/')

soup = BeautifulSoup(r.content, 'html.parser')

ip = soup.find('li', class_='client__item_type_ipv4').\
    find('div', class_='client__desc').text
loc = soup.find('li', class_='client__item_type_location').\
    find('div', class_='client__desc').text
loc = re.sub('\s?Настроить', '', loc)

ip, loc
# Out:
# ('–', 'Москва')

# %% [markdown]
# http://spys.one/proxys/DE/

# %%
proxies = { 'https': '207.180.233.72:80' }
r = requests.get('https://yandex.ru/internet/', proxies=proxies)

soup = BeautifulSoup(r.content, 'html.parser')

ip = soup.find('li', class_='client__item_type_ipv4').\
    find('div', class_='client__desc').text
loc = soup.find('li', class_='client__item_type_location').\
    find('div', class_='client__desc').text
loc = re.sub('\s?Настроить', '', loc)

ip, loc
# Out:
# ('207.180.233.72', 'Берлин')

# %% [markdown]
# ## Selenium
#
# <img width = '500px' src="https://cdn-a.william-reed.com/var/wrbm_gb_food_pharma/storage/images/publications/food-beverage-nutrition/nutraingredients.com/news/research/selenium-may-protect-against-epileptic-seizures-mouse-study-suggests/7690019-1-eng-GB/Selenium-may-protect-against-epileptic-seizures-mouse-study-suggests_wrbm_large.jpg">
#
# http://selenium-python.readthedocs.io/
#
# https://kreisfahrer.gitbooks.io/selenium-webdriver/

# %%
url_format = "http://www.banki.ru/banks/map/{city}/#/!b1:{bank_ids}!s3:{bank_types}!s4:list!p1:{page}"

# %%
url_params = {
    'city': 'lyubertssyi',
    'bank_ids': 'all',
    'bank_types': 'all',
    'page': 1,
}

# %%
url_current = url_format.format(**url_params)
url_current
# Out:
# 'http://www.banki.ru/banks/map/lyubertssyi/#/!b1:all!s3:all!s4:list!p1:1'

# %% [markdown]
# https://www.banki.ru/banks/map/lyubertssyi/#/!b1:all!s3:all!s4:list!p1:1

# %%
r = requests.get(url_current).content

# %%
# find '<script id="list-template">'

soup = BeautifulSoup(r, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html class="env-no-js env-desktop " prefix="ya: http://webmaster.yandex.ru/vocabularies/
# og: http://ogp.me/ns#" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <link href="/favicon.ico?_v=1553792368" rel="icon" type="image/x-icon"/>
#   <meta content="app-id=597405601" name="apple-itunes-app"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <title>
#    Банкоматы Люберец, список отделений банков в г. Люберцы на карте | Банки.ру
#   </title>
#   <meta content="банк, Люберцы, банкоматы, филиалы, карта, телефон, режим работы" name="keywords">
#    <meta content="Актуальный список банкоматов, отделений, офисов и филиалов банков Люберец: адреса, телефоны, режим работы и расположение на карте" name="description"/>
#    <meta content="index, follow" name="robots"/>
#    <meta content="243196695801552" property="fb:app_id"/>
#    <meta content="Банки.ру" property="og:site_name"/>
#    <meta content="Подбор и сравнение банковских, страховых и инвестиционных продуктов онлайн" property="og:description"/>
#    <meta content="https://www.banki.ru/static/bundles/NewsBundle/images/1200x630-logo.jpg" property="og:image"/>
#    <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#    <meta content="Банкоматы Люберец, список отделений банков в г. Люберцы на карте | Банки.ру" property="og:title"/>
#    <meta content="website" property="og:type"/>
#    <meta content="https://www.banki.ru/banks/map/lyubertssyi/" property="og:url"/>
#    <link href="/static/common/dist/common.css?ea68051fbc" rel="stylesheet"/>
#    <link href="/static/common/dist/bankiru-layout.css?df9f122137" rel="stylesheet"/>
#    <link href="/main-bitrix.css?_v=1553792368" rel="stylesheet"/>
#    <link href="/static/bundles/BanksBundle/banks-on-map/appf203693bad82780d93da.css" rel="stylesheet"/>
#    <script>
#     var banki = {
# 		ui: {},
# 		utils: {},
# 		modules: {},
# 		env: {
# 			envValue: 'production',
# 			devMode: false,
# 			browser: {},
# 			isModernDesign: true,
# 			isLocalStorage: 'localStorage' in window || typeof localStorage === 'object',
# 			time: 1553810893000, // current timestamp in milliseconds
# 			timezoneOffset: 10800000,
# 			isMobileMode: false,
# 			isMobileDevice: false,
# 			getIsSmallScreen: function() {
# 				var width = Math.max(document.documentElement.clientWidth, window.innerWidth || 0);
# 				var height = Math.max(document.documentElement.clientHeight, window.innerHeight || 0);
# 				return (width + height) < 1200;
# 			},
# 			isTouchDevice: 'ontouchstart' in window || navigator.msMaxTouchPoints,
# 			isNewAuth: true
# 		},
# 			};
#
# 	// Check is js available
# 	document.documentElement.classList.remove('env-no-js');
# 	document.documentElement.classList.add('env-js');
#
# 	if ('ontouchstart' in window || navigator.maxTouchPoints) {
# 		document.documentElement.classList.add('env-touch');
# 	} else {
# 		document.documentElement.classList.add('env-no-touch');
# 	}
#    </script>
#    <script>
#     banki.utils.domReady = (function() {
# 		var funcArray = [];
# 		var devMode = banki.env.devMode;
#
# 		return {
# 			push: function(callback) {
# 				funcArray.push(callback);
# 			},
# 			run: function() {
# 				this.runCount++;
# 				while (funcArray.length > 0) {
# 					(function() {
# 						var func = funcArray.shift(),
# 							start, end, delta;
#
# 						if (typeof func === 'function') {
# 							setTimeout(function() {
# 								start = new Date();
# 								func();
# 								end = new Date();
# 								delta = end - start;
# 								if (devMode && delta > 100) {
# 									console.warn(func, delta + ' мс');
# 								}
# 							}, 0);
# 						}
# 					})();
# 				}
# 			},
# 			runCount: 0
# 		}
# 	})();
#    </script>
#    <script src="/static/common/dist/main-head.js?cb97ecd0b9">
#    </script>
#    <script>
#     if (navigator.userAgent.indexOf("WebKit") != -1) {
# 				document.querySelector('html').classList.add('env-webkit');
# 			}
#    </script>
#    <!-- Google Tag Manager -->
#    <script>
#     (function(w,d,s,l,i){
# 		w[l]=w[l]||[];
# 		w[l].push({
# 			'gtm.start': new Date().getTime(),
# 			event: 'gtm.js'
# 		});
# 		var f=d.getElementsByTagName(s)[0], j=d.createElement(s), dl=l!='dataLayer'?'&l='+l:'';
# 		j.async=true;
# 		j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;
# 		f.parentNode.insertBefore(j,f);
# 	})(window,document,'script','dataLayer','GTM-TSSMNLH');
#    </script>
#    <!-- End Google Tag Manager -->
#   </meta>
#  </head>
#  <body>
#   <!-- Yandex.Metrika counter -->
#   <script type="text/javascript">
#    (function (d, w, c) {
# 		(w[c] = w[c] || []).push(function() {
# 			try {
# 				w.yaCounter502212 = new Ya.Metrika({ id:502212, clickmap:true, trackLinks:true, accurateTrackBounce:true, webvisor:true, ut:"noindex" });
# 			} catch(e) { }
# 		});
#
# 		var n = d.getElementsByTagName("script")[0],
# 			s = d.createElement("script"),
# 			f = function () { n.parentNode.insertBefore(s, n); };
# 		s.type = "text/javascript";
# 		s.async = true;
# 		s.src = "https://mc.yandex.ru/metrika/watch.js";
#
# 		if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# 	})(document, window, "yandex_metrika_callbacks");
#   </script>
#   <noscript>
#    <div>
#     <img alt="" src="https://mc.yandex.ru/watch/502212?ut=noindex" style="position:absolute; left:-9999px;"/>
#    </div>
#   </noscript>
#   <!-- /Yandex.Metrika counter -->
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TSSMNLH" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-38591118-1', 'auto');
# 	ga('require', 'displayfeatures');
# 	ga(function(tracker) {
# 		/* BD-1184 */
# 		var clientId = tracker.get('clientId') || '(cid not found)';
# 		tracker.set('dimension1', clientId);
# 	});
# 	ga(function(tracker) {
# 		/* BD-1004 */
# 		var clientId = tracker.get('clientId') || '(cid not found)';
# 		var date = new Date(new Date().getTime() + 1000 * 60 * 60 * 24 * 365); // 1 год
# 		document.cookie = 'ga_client_id=' + clientId + '; path=/; expires=' + date.toUTCString();
# 	});
#   </script>
#   <div class="bitrix-component" data-group="banners" data-name="custom:advertising.block" data-params='{"BANNER_TYPE":"Background_Full","CODE":"Banner"}' data-template="background">
#   </div>
#   <header class="header">
#    <div class="padding-top-x-small padding-bottom-x-small" data-header-banner="">
#     <div class="bitrix-component" data-group="banners" data-init-inner-modules="1" data-name="custom:advertising.block" data-params='{"BANNER_TYPE":"branding","CODE":"top_rotation"}' data-template="branding-hor-rotation">
#     </div>
#     <div data-dfp-container="">
#      <div class="js-dfp-banners dfp-banner" data-dfp-name="allPagesTop">
#      </div>
#     </div>
#    </div>
#    <div class="bitrix-component" data-group="banners" data-init-inner-modules="1" data-name="custom:advertising.block" data-params='{"BANNER_TYPE":"Branding_Wall","CODE":"Banner"}' data-template="branding_wall">
#    </div>
#    <div class="layout-wrapper">
#     <div class="border-bottom-solid">
#      <div class="header-toolbar border-top-solid-gray border-bottom-solid-gray bg-white" data-test="header-toolbar">
#       <div class="header-location" data-test="region-select">
#        <span class="link-with-icon link-with-icon--gray-to-blue">
#         <i class="link-with-icon__icon icon-font icon-font--medium icon-location-24">
#         </i>
#         <span class="link-with-icon__text pseudo-link" data-init="layout.region-select">
#         </span>
#        </span>
#       </div>
#       <script>
#        banki.utils.domReady.push(function() {
# 		require(['layout.region-select'], function (RegionSelect) {
# 			new RegionSelect(document.querySelector('[data-init="layout.region-select"]'),
# 				{
# 					ajaxUrl: '/ajax/widget.php?widget=App\\Widgets\\Common\\RegionSelector\\RegionSelector&type=city',
# 					topList: [
# 						{
# 							id: '4',
# 							name: 'Москва',
# 							selected: 'true'
# 						},
# 						{
# 							id: '211',
# 							name: 'Санкт-Петербург',
# 							selected: ''
# 						}
# 					],
# 					selectedRegion: '4',
# 					togglerText: 'Москва',
# 					footer: '<a class="cursor-pointer" data-footer data-region-id="1">Вся Россия</a>'
# 				}
# 			);
# 		});
# 	});
#       </script>
#       <div class="flexbox flexbox--row flexbox--gap_medium">
#        <div class="header-auth" data-test="header-auth">
#         <a class="link-with-icon link-with-icon--gray-to-blue" data-click="show-auth-popup" href="/auth/?type=login">
#          <i class="link-with-icon__icon icon-font icon-font--medium icon-user-24">
#          </i>
#          <span class="link-with-icon__text pseudo-link">
#           Вход
#          </span>
#         </a>
#        </div>
#        <div class="header-search" data-module="layout.header-search" data-module-immediately="" data-search-container="" data-test="header-search">
#         <span class="link-with-icon link-with-icon--gray-to-blue cursor-pointer" data-click="open-search">
#          <i class="link-with-icon__icon icon-font icon-font--medium icon-magnifier-24">
#          </i>
#          <span class="link-with-icon__text pseudo-link">
#           Поиск
#          </span>
#         </span>
#         <div class="header-search__field" data-search-bar="">
#          <div class="header-search__field__input">
#           <form action="/search/" class="item__node item__node--input js-search-input-form" data-module="search-input" method="get">
#            <input name="utf8" type="hidden" value="1"/>
#            <div class="input-search" data-test="global-search">
#             <input class="input-search__button" data-test="submit-search-button" name="s" type="submit" value=""/>
#             <input class="input-search__field" data-test="input-search" name="q" placeholder="Поиск по сайту" type="search" value=""/>
#            </div>
#           </form>
#          </div>
#          <div class="header-search__field__close" data-click="close-search">
#           <i class="icon-font icon-close color-gray-blue">
#           </i>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="header-content" data-test="header-content">
#       <div class="header-content__logo">
#        <a href="/" style="width: 250px; display: block;" title="banki.ru • информационный портал">
#         <img alt="banki.ru" class="ui-image" src="/static/common/common/img/bankiru-logo.svg?688977b5c7"/>
#        </a>
#       </div>
#       <div class="header-content__banner" data-test="header-content-banner">
#        <div data-dfp-container="">
#         <div class="js-dfp-banners dfp-banner" data-dfp-name="allPagesHeader1">
#         </div>
#        </div>
#       </div>
#       <div class="header-content__banner" data-test="header-content-banner">
#        <div data-dfp-container="">
#         <div class="js-dfp-banners dfp-banner" data-dfp-name="allPagesHeader2">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </header>
#   <div class="layout-wrapper">
#    <nav class="main-menu" data-init="layout.mainMenu">
#     <ul class="main-menu__sections">
#      <li class="main-menu__sections__item main-menu__sections__item--active main-menu__sections__item--bank">
#       <a href="/" onclick="_gaq.push(['_trackEvent', 'topmenu', 'click', 'banks'])">
#        Банки
#       </a>
#       <ul class="main-menu__subsections" data-subsections-wrap="" data-test-comp="main-menu-subsections">
#        <li class="main-menu__subsections__item main-menu__subsections__item--deposits " data-subsection="">
#         <div class="main-menu__subsections__name" data-test-comp="subsections-item">
#          Вклады
#         </div>
#         <div class="main-menu__submenu main-menu__submenu--deposits main-menu__submenu--bank" data-submenu="">
#          <div class="main-menu__submenu__columns">
#           <div class="main-menu__submenu__column" data-test-comp="submenu-column">
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/deposits/" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'deposits']);">
#              Вклады
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/specials/" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'lenta']);">
#              Специальные предложения
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/deposits/search/?special=14&amp;payment_period%5B0%5D=1&amp;payment_period%5B1%5D=2&amp;payment_period%5B2%5D=3&amp;payment_period%5B3%5D=4&amp;payment_period%5B4%5D=5&amp;payment_period%5B5%5D=6&amp;payment_period%5B6%5D=7&amp;payment_period%5B7%5D=8">
#              Накопительные счета
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/services/calculators/deposits/">
#              Калькулятор вкладов
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/mydeposits/">
#              Мои вклады
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="main-menu__subsections__item main-menu__subsections__item--credits " data-subsection="">
#         <div class="main-menu__subsections__name" data-test-comp="subsections-item">
#          Кредиты
#         </div>
#         <div class="main-menu__submenu main-menu__submenu--credits main-menu__submenu--bank" data-submenu="">
#          <div class="main-menu__submenu__columns">
#           <div class="main-menu__submenu__column" data-test-comp="submenu-column">
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/credits/" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'credits']);">
#              Потребительские кредиты
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/restructing/">
#              Рефинансирование
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/creditcards/">
#              Кредитные карты
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/autocredits/" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'autocredits']);">
#              Автокредиты
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/microloans/">
#              Микрозаймы
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/hypothec/" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'hypothec']);">
#              Ипотечные кредиты
#             </a>
#            </div>
#           </div>
#           <div class="main-menu__submenu__column" data-test-comp="submenu-column">
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/credit-master/" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'prod_creditmaster']);" target="_blank">
#              Мастер подбора кредитов
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/services/calculators/credits/">
#              Калькулятор кредитов
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/services/calculators/autocredits/">
#              Калькулятор автокредитов
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/mycreditinfo/">
#              Кредитные истории
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/paycredits/" target="_blank">
#              Оплата кредита онлайн
#             </a>
#            </div>
#           </div>
#          </div>
#          <a class="link-block padding-default" href="/loto/creditloto/?source=creditloto_menu_bottom" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'creditloto_bottom']);" style="background: linear-gradient(135deg, #3854C1 0%, #79258B 100%);" target="_blank">
#           <div class="flexbox flexbox--row flexbox--gap_default flexbox--align-items_center">
#            <div>
#             <img alt="КРЕДИТЛОТО" class="lazy-load" data-src="/static/bundles/BigDataBundle/loto/creditloto/images/credit-loto-top-menu-logo.47907aa8581698a22a299b229eaa34ce.svg"/>
#            </div>
#            <div class="color-light-mustard font-bold font-size-medium">
#             Получите кредит или кредитную карту и выиграйте 4 000 ₽!
#            </div>
#            <div>
#             <div class="button button--small button--gray">
#              Участвовать
#             </div>
#            </div>
#           </div>
#          </a>
#         </div>
#        </li>
#        <li class="main-menu__subsections__item main-menu__subsections__item--cards " data-subsection="">
#         <div class="main-menu__subsections__name" data-test-comp="subsections-item">
#          Карты
#         </div>
#         <div class="main-menu__submenu main-menu__submenu--cards main-menu__submenu--bank" data-submenu="">
#          <div class="main-menu__submenu__columns">
#           <div class="main-menu__submenu__column" data-test-comp="submenu-column">
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/creditcards/">
#              Кредитные карты
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/creditcards/search/moskva/?is_installment=1">
#              Карты рассрочки
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/debitcards/">
#              Дебетовые карты
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/mir/">
#              НПК «Мир»
#             </a>
#            </div>
#           </div>
#           <div class="main-menu__submenu__column" data-test-comp="submenu-column">
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/creditcard-master/">
#              Мастер подбора кредитных карт
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/services/calculators/debitcards/">
#              Калькулятор Cash Back
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="https://card2card.banki.ru/card2card/ptpl/banki/initial.html" target="_blank">
#              Перевод с карты на карту
#             </a>
#            </div>
#           </div>
#          </div>
#          <a class="link-block padding-default" href="/loto/creditloto/?source=creditloto_menu_bottom" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'creditloto_bottom']);" style="background: linear-gradient(135deg, #3854C1 0%, #79258B 100%);" target="_blank">
#           <div class="flexbox flexbox--row flexbox--gap_default flexbox--align-items_center">
#            <div>
#             <img alt="КРЕДИТЛОТО" class="lazy-load" data-src="/static/bundles/BigDataBundle/loto/creditloto/images/credit-loto-top-menu-logo.47907aa8581698a22a299b229eaa34ce.svg"/>
#            </div>
#            <div class="color-light-mustard font-bold font-size-medium">
#             Получите кредит или кредитную карту и выиграйте 4 000 ₽!
#            </div>
#            <div>
#             <div class="button button--small button--gray">
#              Участвовать
#             </div>
#            </div>
#           </div>
#          </a>
#         </div>
#        </li>
#        <li class="main-menu__subsections__item main-menu__subsections__item--mortgage " data-subsection="">
#         <div class="main-menu__subsections__name" data-test-comp="subsections-item">
#          Ипотека
#         </div>
#         <div class="main-menu__submenu main-menu__submenu--mortgage main-menu__submenu--bank" data-submenu="">
#          <div class="main-menu__submenu__columns">
#           <div class="main-menu__submenu__column" data-test-comp="submenu-column">
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/hypothec/" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'hypothec']);">
#              Ипотечные кредиты
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/hypothec/catalogue/ipoteka_na_kvartiru_na_vtorichnom_ryinke/">
#              На вторичном рынке
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/hypothec/catalogue/ipoteka_na_kvartiru_v_novostroyke/">
#              На новостройки
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/hypothec/catalogue/refinansirovanie_ipoteki/">
#              Рефинансирование
#             </a>
#            </div>
#           </div>
#           <div class="main-menu__submenu__column" data-test-comp="submenu-column">
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/hypothec-master/">
#              Мастер подбора ипотеки
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/services/calculators/hypothec/">
#              Калькулятор ипотеки
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/mycreditinfo/">
#              Кредитные истории
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/insurance/order/realty/mortgage/">
#              Ипотечное страхование
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="main-menu__subsections__item main-menu__subsections__item--business " data-subsection="">
#         <div class="main-menu__subsections__name" data-test-comp="subsections-item">
#          Для бизнеса
#         </div>
#         <div class="main-menu__submenu main-menu__submenu--business main-menu__submenu--bank" data-submenu="">
#          <div class="main-menu__submenu__columns">
#           <div class="main-menu__submenu__column" data-test-comp="submenu-column">
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/rko/" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'rko']);" target="_blank">
#              РКО
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/businesscredits/">
#              Кредиты для бизнеса
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/leasing/">
#              Лизинг
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="main-menu__subsections__item main-menu__subsections__item--banks main-menu__subsections__item--selected " data-subsection="">
#         <div class="main-menu__subsections__name" data-test-comp="subsections-item">
#          Банки и рейтинги
#         </div>
#         <div class="main-menu__submenu main-menu__submenu--banks main-menu__submenu--bank" data-submenu="">
#          <div class="main-menu__submenu__columns">
#           <div class="main-menu__submenu__column" data-test-comp="submenu-column">
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/banks/moskva/">
#              Банки Москвы
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/banks/" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'banks']);">
#              Банки России
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/microloans/companies/">
#              Микрофинансовые организации
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item" title="Национальная платежная карта «Мир»">
#             <a href="/mir/">
#              НПК «Мир»
#             </a>
#            </div>
#            <div class="main-menu__submenu__item main-menu__submenu__item--selected " data-test-comp="submenu-column-item">
#             <a href="/banks/map/" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'map']);">
#              Банки на карте
#             </a>
#            </div>
#           </div>
#           <div class="main-menu__submenu__column" data-test-comp="submenu-column">
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/bankofyear/2018/tickets/" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'bankgoda2018']);" target="_blank">
#              Банк года
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/banks/memory/">
#              Книга памяти
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/bki/">
#              Бюро кредитных историй
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/banks/vacancy/">
#              Вакансии банков
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/banks/vacancy/resumes/">
#              Резюме специалистов
#             </a>
#            </div>
#           </div>
#           <div class="main-menu__submenu__column" data-test-comp="submenu-column">
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/services/responses/" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'responses']);">
#              Народный рейтинг банков
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/banks/ratings/">
#              Финансовые показатели
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/banks/ratings/agency/">
#              Кредитные рейтинги
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/services/official/">
#              Служебный рейтинг
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="main-menu__subsections__item main-menu__subsections__item--news " data-subsection="">
#         <div class="main-menu__subsections__name" data-test-comp="subsections-item">
#          Новости
#         </div>
#         <div class="main-menu__submenu main-menu__submenu--news main-menu__submenu--bank" data-submenu="">
#          <div class="main-menu__submenu__columns">
#           <div class="main-menu__submenu__column" data-test-comp="submenu-column">
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/news/">
#              Все события дня
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/news/lenta/">
#              Лента новостей
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/news/daytheme/">
#              Тема дня
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/news/bankpress/">
#              Обзор прессы
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/news/stars/">
#              Звезды в банке
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/news/video/">
#              Видео
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/news/columnists/" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'columnists']);" rel="nofollow">
#              Мнение
#             </a>
#            </div>
#           </div>
#           <div class="main-menu__submenu__column" data-test-comp="submenu-column">
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/news/columnists/?author=9920478">
#              ФинСуп
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="https://tests.banki.ru/">
#              Тесты
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/news/research/">
#              Исследования
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/news/pressreleases/">
#              Пресс-релизы
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/news/partners/">
#              Партнерские материалы
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/news/events/">
#              Мероприятия
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/wikibank/" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'wikibank']);" rel="nofollow">
#              Банковский словарь
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="main-menu__subsections__item main-menu__subsections__item--more " data-subsection="">
#         <div class="main-menu__subsections__name" data-test-comp="subsections-item">
#          <span class="icon-font icon-font--medium icon-font--size_medium icon-more-24">
#          </span>
#         </div>
#         <div class="main-menu__submenu main-menu__submenu--more main-menu__submenu--bank" data-submenu="">
#          <div class="main-menu__submenu__columns">
#           <div class="main-menu__submenu__column" data-test-comp="submenu-column">
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/currency/">
#              Курсы обмена валют
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/products/currency/cb/" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'cb']);">
#              Курсы ЦБ
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="https://bankiru.go2cloud.org/aff_c?offer_id=1553&amp;aff_id=2&amp;cid=1640288839.1542026218" target="_blank">
#              Онлайн обмен валюты
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/bonus/">
#              Бонусный клуб
#             </a>
#            </div>
#           </div>
#           <div class="main-menu__submenu__column" data-test-comp="submenu-column">
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/forum/">
#              Форум
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/services/responses/list/">
#              Отзывы о банках
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/services/questions-answers/">
#              Вопрос-ответ
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/friends/">
#              Блоги
#             </a>
#            </div>
#            <div class="main-menu__submenu__item " data-test-comp="submenu-column-item">
#             <a href="/news/events/">
#              Мероприятия
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </li>
#       </ul>
#      </li>
#      <li class="main-menu__sections__item">
#       <a href="/insurance/" onclick="_gaq.push(['_trackEvent', 'topmenu', 'click', 'insurance'])">
#        Страхование
#       </a>
#      </li>
#      <li class="main-menu__sections__item">
#       <a href="/investment/" onclick="_gaq.push(['_trackEvent', 'topmenu', 'click', 'investment'])">
#        Инвестиции
#       </a>
#      </li>
#      <li class="main-menu__sections__item">
#       <a href="/telecom/" onclick="_gaq.push(['_trackEvent', 'topmenu', 'click', 'telecom'])">
#        Связь и интернет
#       </a>
#      </li>
#      <li class="main-menu__sections__item main-menu__sections__item--alternative">
#       <a href="/credit-master/?source=mainmenu_icon" onclick="_gaq.push(['_trackEvent', 'mainmenu', 'click', 'master'])" target="_blank">
#        <img class="lazy-load" data-src="/static/bundles/BigDataBundle/credit-master/images/credit-master-menu.e432fe3732b3b418f770801a14c3be54.gif" style="transform: translateY(-4px)"/>
#       </a>
#      </li>
#     </ul>
#    </nav>
#    <script>
#     banki.utils.domReady.push(function () {
# 			require(['layout.mainMenu'], function (Menu) {
# 				new Menu(document.querySelector('[data-init="layout.mainMenu"]'));
# 			});
# 		});
#    </script>
#   </div>
#   <div class="layout-wrapper padding-top-default padding-bottom-large border-default bg-white position-relative" style="display: block;">
#    <a class="anchor" name="area-body">
#    </a>
#    <nav class="bread-crumbs" data-test="bread-crumbs" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#     <a class="bread-crumbs__item bread-crumbs__item--first" href="/" itemprop="url" title="Главная страница">
#      <span itemprop="title">
#       Главная
#      </span>
#     </a>
#     <span class="bread-crumbs__item bread-crumbs__item--separator">
#      •
#     </span>
#     <span class="bread-crumbs__item" itemprop="child" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#      <a href="/banks/" itemprop="url">
#       <span itemprop="title">
#        Банки
#       </span>
#      </a>
#     </span>
#     <span class="bread-crumbs__item bread-crumbs__item--separator">
#      •
#     </span>
#     <span class="bread-crumbs__item" itemprop="child" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#      <span itemprop="title">
#       Банки на карте Люберец
#      </span>
#      <a href="https://www.banki.ru/banks/map/lyubertssyi/" itemprop="url">
#      </a>
#     </span>
#    </nav>
#    <script type="application/ld+json">
#     { "@context": "http://schema.org", "@type": "BreadcrumbList", "itemListElement": [
# 																							{ "@type": "ListItem", "position": 1, "item": { "@id": "https://www.banki.ru/banks/", "name": "Банки" }},																			{ "@type": "ListItem", "position": 2, "item": { "@id": "https://www.banki.ru/banks/map/lyubertssyi/", "name": "Банки на карте Люберец" }}							]}
#    </script>
#    <header class="layout-column-center" data-breadcrumbs="">
#     <h1 class="header-h0">
#      Банкоматы и отделения банков на карте Люберец
#     </h1>
#     <p class="header-subtitle">
#      Адреса банкоматов, отделений и филиалов банков Люберец, телефоны, режим работы и другая информация о банках
#     </p>
#    </header>
#    <section class="layout-column-full" data-bank-id="" data-bank-name="" data-region-area-name="Другие" data-region-id="54" data-region-name="Люберцы" id="bank-branch">
#     <div class="branches__filter branches__filter--gray branches__filter--padded branches__filter--margin-bottom" id="branches__filter">
#      <div class="branches__filter__row">
#       <div class="branches__filter__city">
#        Город:
#        <span class="pseudo-link" id="universal-select-region__trigger">
#         Люберцы
#        </span>
#        <script>
#         banki.utils.domReady.push(function() {
#         require(['universal-select-region'], function(module) {
#             module.initialize({
#                 active: "Люберцы",
#                 bankId: "0",
#                 bankName: "",
#                 regionName: "Люберцы",
#                 baseUrl: "/banks/map/",
#                 appendUrl: ""
#             });
#         });
#     });
#        </script>
#       </div>
#       <div class="branches__filter__bank">
#        <div class="bank-choice bank-choice--hidden">
#         <span>
#          Банк:
#         </span>
#         <span class="bank-choice__chosen-items">
#         </span>
#         <span class="bank-choice__link-wrapper">
#          <span class="bank-choice__link pseudo-link">
#           Выбрать
#          </span>
#         </span>
#        </div>
#       </div>
#       <div class="branches__filter__clear">
#        <span class="filter__clear__chose filter__clear__chose--hidden">
#         <span class="filter__clear__chose__link pseudo-link">
#          Очистить фильтр
#         </span>
#         <span class="filter__clear__chose__close">
#         </span>
#        </span>
#       </div>
#      </div>
#      <div class="branches__filter__row">
#       <div class="branches__filter__types">
#        <div class="button-group">
#         <a class="filter__types__button button button--blue button--w30persent" data-type="all" href="" rel="nofollow">
#          Все
#         </a>
#         <a class="filter__types__button button button--blue button--w30persent" data-type="office" data-url="" href="">
#          Офисы
#         </a>
#         <a class="filter__types__button button button--blue button--w30persent" data-type="bankomaty" href="">
#          Банкоматы
#         </a>
#        </div>
#       </div>
#       <div class="branches__filter__search">
#        <div class="filter__dropdown animated">
#        </div>
#        <input autocomplete="no" class="filter__search__input input--full-width" placeholder="Найти адрес или метро" type="text"/>
#        <button class="filter__search__button" type="submit">
#        </button>
#        <!--                <button type="submit" class="filter__search__button"><span class="icon-font icon-search"></span></button>-->
#       </div>
#      </div>
#     </div>
#     <div class="branches__legend" id="branches__legend">
#      <div class="branches__legend__item branches__legend__item--office">
#       головные офисы
#      </div>
#      <div class="branches__legend__item branches__legend__item--branch" data-type="office">
#       офисы
#      </div>
#      <div class="branches__legend__item branches__legend__item--atm" data-type="bankomaty">
#       банкоматы
#      </div>
#     </div>
#     <div class="clearfix margin-bottom-small" id="branches__switch">
#      <ul class="ui-button-switcher">
#       <li>
#        <a class="switcher__button switcher__button--active" data-type="map">
#         <i class="icon-font icon-map">
#         </i>
#         <span>
#          на карте
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="switcher__button switcher__button--active" data-type="list">
#         <i class="icon-font icon-list">
#         </i>
#         <span>
#          списком
#         </span>
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="branches__map branches__map--hidden" id="branches__map">
#      <div class="map__error animated">
#      </div>
#     </div>
#     <div class="branches__list branches__list--hidden" id="branches__list">
#     </div>
#     <div class="branches__viewer__overlay">
#     </div>
#     <div class="branches__viewer" id="branches__viewer">
#      <span class="viewer__close">
#      </span>
#      <div class="viewer__content">
#       <span class="viewer__title">
#       </span>
#       <span class="viewer__address">
#       </span>
#       <div class="viewer__map" id="viewer__map">
#       </div>
#      </div>
#      <div class="viewer__report">
#       <div class="report__choice">
#        <span class="report__choice__label pseudo-link">
#         Сообщить об ошибке
#        </span>
#        <ul class="report__choice__list animated">
#         <li class="report__choice__item" data-choice="address">
#          Адрес
#         </li>
#         <li class="report__choice__item" data-choice="work_time">
#          Время работы
#         </li>
#         <li class="report__choice__item" data-choice="place">
#          Расположение на карте
#         </li>
#         <li class="report__choice__item" data-choice="not_map">
#          Не должно быть на карте
#         </li>
#         <li class="report__choice__item" data-choice="other">
#          Другое
#         </li>
#        </ul>
#       </div>
#       <form class="report__form">
#        <div class="report__form__row">
#         <select class="report__form__type report__form__select" name="error_type">
#          <option class="report__form__select__option" value="place">
#           Неверное расположение на карте
#          </option>
#          <option class="report__form__select__option" value="not_map">
#           Не должно быть на карте
#          </option>
#          <option class="report__form__select__option" value="address">
#           Неверный адрес
#          </option>
#          <option class="report__form__select__option" value="work_time">
#           Неверное время работы
#          </option>
#          <option class="report__form__select__option" value="other">
#           Другое
#          </option>
#         </select>
#        </div>
#        <div class="report__form__row">
#         <label class="report__form__label">
#          Укажите правильный адрес:
#         </label>
#         <textarea class="report__form__message report__form__textarea" name="user_message"></textarea>
#        </div>
#        <div class="report__form__row">
#         <input class="report__form__name report__form__input" name="user_name" placeholder="Ваше имя" type="text" value=""/>
#         <input class="report__form__email report__form__input" name="user_email" placeholder="Ваше e-mail" type="text" value=""/>
#        </div>
#        <div class="report__form__row">
#         <button class="report__form__confirm report__form__submit button button--orange" type="button">
#          Отправить
#         </button>
#         <button class="report__form__cancel report__form__submit button button--blue" type="button">
#          Отменить
#         </button>
#         <div class="report__error">
#         </div>
#        </div>
#       </form>
#       <div class="report__message">
#        Спасибо, мы приняли ваше сообщение!
#        <br/>
#        Возможно, мы свяжемся с вами для
# 					уточнения информации или сообщим об исправлении ошибки.
#        <br/>
#        Мы благодарны вам за желание сделать наш
# 					сервис лучше!
#       </div>
#      </div>
#     </div>
#    </section>
#    <script id="filter__dropdown-template" type="text/x-handlebars-template">
#     <ul class="filter__dropdown__list">
# 			{{#each items}}
# 			<li class="{{this.cls}}" data-kind="{{this.kind}}" data-coordinates="{{this.coordinates}}" data-name="{{this.name}}" data-description="{{this.description}}">
# 				<div class="filter__dropdown__item__name">{{{this.name}}}</div>
# 				<div class="filter__dropdown__item__desc">{{{this.description}}}</div>
# 			</li>
# 			{{/each}}
# 		</ul>
#    </script>
#    <script id="list-template" type="text/x-handlebars-template">
#     <div class="list__header">
# 			<span class="list__header__title-region"><span>Область карты <i class="list__header__title-region__close"></i></span></span>
# 			<span class="list__header__title">Найдено <span>{{{total}}}</span> объектов</span>
# 			<span class="list__header__pagination">
# 			{{#if pages}}
# 				<div class="ui-pagination float-right">
# 					<ul class="ui-pagination__list">
#
# 						<li class="ui-pagination__item" data-direction="prev">
# 							<a href="#" class="icon-font icon-arrow-previous" data-direction="prev"></a>
# 						</li>
#
# 						{{#each pages}}
# 						{{#if this.page}}
# 						<li class="ui-pagination__item" data-page="{{{this.page}}}">
# 							<a href="#" data-page="{{{this.page}}}">{{{this.page}}}</a>
# 						</li>
# 						{{/if}}
#
# 						{{#unless this.page}}
# 						<li class="ui-pagination__item">...</li>
# 						{{/unless}}
# 						{{/each}}
#
# 						<li class="ui-pagination__item" data-direction="next">
# 							<a href="#" class="icon-font icon-arrow-next" data-direction="next"></a>
# 						</li>
# 					</ul>
# 				</div>
# 				{{/if}}
# 		</span>
# 		</div>
# 		<div class="list__main">
# 			<ul class="list">
# 				<li class="list__item list__item--header">
# 					<span class="item__name">Название</span>
# 					<span class="item__location">Адрес</span>
# 					<span class="item__schedule">Режим работы</span>
# 					<span class="item__additional">Услуги и особенности</span>
# 				</li>
# 				{{#each branches}}
# 				<li class="list__item" data-id="{{this.id}}" data-latitude="{{this.latitude}}" data-longitude="{{this.longitude}}" data-name="{{this.name}}" data-address="{{this.address}}" data-type="{{this.type}}">
# 					<div class="item__icon">
# 						<span class="icon-font icon-{{this.type}}"></span>
# 					</div>
# 					<div class="item__name">
# 						{{#ifCond this.name '&&' this.show_on_banki}}
# 						<a href="/banks/bank/branches/?ID={{this.id}}" class="item__name__link">{{{this.name}}}</a>
# 						{{else}}
# 						{{{this.name}}}<br/>
# 						{{/ifCond}}
# 						{{#if this.bank_name}}
# 						<a href="/banks/bank/{{this.bank_code}}/" class="item__name__bank">{{{this.bank_name}}}</a>
# 						{{/if}}
# 					</div>
# 					<div class="item__location">
# 						{{#if this.address}}
# 						<span class="item__location__address">
# 							<span class="item__location__address__link pseudo-link" data-href="/banks/bank/branches/?ID={{this.id}}">{{{this.address}}}</span>
# 						</span>
# 						{{/if}}
# 						{{#if this.comment_to_address}}
# 						<span class="item__location__comment_to_address">
# 							{{{this.comment_to_address}}}
# 						</span>
# 						{{/if}}
# 						{{#if this.metro_name}}
# 						<div><span class="icon-font icon-metro"></span> {{{this.metro_name}}}</span></div>
# 						{{/if}}
# 						{{#if this.phone}}
# 						<span class="item__location__phone">{{{this.phone}}}</span>
# 						{{/if}}
# 					</div>
# 					<div class="item__schedule">
# 						{{#if this.schedule_general}}
# 						<span class="item__schedule__group">
# 							<span class="item__schedule__group__content">{{{this.schedule_general}}}</span>
# 						</span>
# 						{{/if}}
# 						{{#if this.schedule_private_person}}
# 						<span class="item__schedule__group">
# ...
# 					{{/if}}
# 			</span>
# 			</div>
# 			{{#if address}}
# 			<span class="map__balloon__content__address">
# 				{{{address}}}
# 			</span>
# 			{{/if}}
# 			{{#if comment_to_address}}
# 			<span class="map__balloon__content__comment_to_address">
# 				{{{comment_to_address}}}
# 			</span>
# 			{{/if}}
# 			{{#if metro_name}}
# 			<span class="map__balloon__content__metro">
# 				 {{{metro_name}}}
# 			</span>
# 			{{/if}}
# 			{{#if phone}}
# 			<span class="map__balloon__content__phone">
# 				{{{phone}}}
# 			</span>
# 			{{/if}}
# 			{{#ifCond schedule_general '||' this.is_round_the_clock}}
# 			<span class="map__balloon__content__schedule">
# 				<span class="map__balloon__content__schedule__title">Режим работы:</span>
# 				{{#if this.is_round_the_clock}}
# 					<span class="map__balloon__content__schedule__content">Круглосуточно</span>
# 				{{/if}}
# 				{{#if schedule_general}}
# 				<span class="map__balloon__content__schedule__content">{{{schedule_general}}}</span>
# 				{{/if}}
# 			</span>
# 			{{/ifCond}}
# 			{{#if schedule_private_person}}
# 			<span class="map__balloon__content__schedule">
# 				<span class="map__balloon__content__schedule__title">Обслуживание физических лиц:</span>
# 				<span class="map__balloon__content__schedule__content">{{{schedule_private_person}}}</span>
# 			</span>
# 			{{/if}}
# 			{{#if schedule_entities}}
# 			<span class="map__balloon__content__schedule">
# 				<span class="map__balloon__content__schedule__title">Обслуживание юридических лиц:</span>
# 				<span class="map__balloon__content__schedule__content">{{{schedule_entities}}}</span>
# 			</span>
# 			{{/if}}
# 			{{#if schedule_vip}}
# 			<span class="map__balloon__content__schedule">
# 				<span class="map__balloon__content__schedule__title">Обслуживание VIP-клиентов:</span>
# 				<span class="map__balloon__content__schedule__content">{{{schedule_vip}}}</span>
# 			</span>
# 			{{/if}}
# 			{{#ifCond this.is_works_as_shop '||' this.is_at_closed_place}}
# 			<span class="map__balloon__content__schedule">
# 			{{#if this.is_works_as_shop}}
# 				<span class="map__balloon__content__schedule__content">Доступен в режиме работы места установки</span>
# 				{{/if}}
# 				{{#if this.is_at_closed_place}}
# 				<span class="map__balloon__content__schedule__content">Банкомат ограниченного доступа</span>
# 				{{/if}}
# 		</span>
# 			{{/ifCond}}
# 			<div class="map__balloon__content__report">
# 				<div class="report__choice">
# 					<span class="report__choice__label pseudo-link">Сообщить об ошибке</span>
# 					<ul class="report__choice__list animated">
# 						<li class="report__choice__item" data-choice="address">Адрес</li>
# 						<li class="report__choice__item" data-choice="work_time">Время работы</li>
# 						<li class="report__choice__item" data-choice="place">Расположение на карте</li>
# 						<li class="report__choice__item" data-choice="not_map">Не должно быть на карте</li>
# 						<li class="report__choice__item" data-choice="other">Другое</li>
# 					</ul>
# 				</div>
# 				<form class="report__form">
# 					<div class="report__form__row">
# 						<select name="error_type" class="report__form__type report__form__select">
# 							<option value="place" class="report__form__select__option">Неверное расположение на карте</option>
# 							<option value="not_map" class="report__form__select__option">Не должно быть на карте</option>
# 							<option value="address" class="report__form__select__option">Неверный адрес</option>
# 							<option value="work_time" class="report__form__select__option">Неверное время работы</option>
# 							<option value="other" class="report__form__select__option">Другое</option>
# 						</select>
# 					</div>
# 					<div class="report__form__row">
# 						<label class="report__form__label">Укажите правильный адрес:</label>
# 						<textarea name="user_message" class="report__form__message report__form__textarea"></textarea>
# 					</div>
# 					<div class="report__form__row">
# 						<input name="user_name" type="text" value="" class="report__form__name report__form__input" placeholder="Ваше имя"/>
# 						<input name="user_email" type="text" value="" class="report__form__email report__form__input" placeholder="Ваше e-mail"/>
# 					</div>
# 					<div class="report__form__row">
# 						<button type="button" class="report__form__confirm report__form__submit button button--orange">Отправить</button>
# 						<button type="button" class="report__form__cancel report__form__submit button button--blue">Отменить</button>
# 						<div class="report__error"></div>
# 					</div>
# 				</form>
# 				<div class="report__message">Спасибо, мы приняли ваше сообщение!<br />Возможно, мы свяжемся с вами для уточнения информации или сообщим об исправлении ошибки.<br />Мы благодарны вам за желание сделать наш сервис лучше!</div>
# 			</div>
# 		</div>
#    </script>
#    <script id="bank__map__balloon__sidebar-template" type="text/x-handlebars-template">
#     {{#each items}}
# 		<li data-bank-id="{{this.bank_id}}">
# 			<span data-toggle="tab" class="color-link cursor-pointer">{{{this.bank_name}}}</span>
# 		</li>
# 		{{/each}}
#    </script>
#    <script type="text/javascript">
#     var objectTypes = '';
# 		var	metaData = {
# 			all: {
# 				title: 'Банкоматы Люберец, список отделений банков в г. Люберцы на карте',
# 				h1: 'Банкоматы и отделения банков на карте Люберец',
# 				h2: 'Адреса банкоматов, отделений и филиалов банков Люберец, телефоны, режим работы и другая информация о банках'
# 			},
# 		};
#
# 		banki.utils.domReady.push(function () {
# 			require([
# 				'/static/bundles/BanksBundle/banks-on-map/app5bec9e4e5a3e867d9d1d.js'
# 			], function (module) {
# 				module.default.init();
# 			});
# 		});
#    </script>
#    <div class="margin-top-large" data-dfp-container="">
#     <div class="js-dfp-banners dfp-banner" data-dfp-name="allPagesBottom">
#     </div>
#    </div>
#   </div>
#   <footer class="footer layout-wrapper">
#    <div class="footer__top-row">
#     <a class="footer__logo-link" href="/" title="banki.ru • информационный портал">
#      <img alt="Банки.ру" class="lazy-load footer__logo-pic" data-src="/static/bundles/Layout2018Bundle/images/footer/logo.b6d0b18df713f78f039858992421a970.png"/>
#     </a>
#     <div class="footer__title">
#      Вся правда о банках ©
#     </div>
#     <ul class="footer__socials-list">
#      <li class="footer__socials-item">
#       <a class="footer__socials-item-link" href="//www.facebook.com/banki.ru" target="_blank">
#        <i class="icon-font icon-font--medium va-middle icon-facebook-24">
#        </i>
#       </a>
#      </li>
#      <li class="footer__socials-item">
#       <a class="footer__socials-item-link" href="//twitter.com/banki_ru" target="_blank">
#        <i class="icon-font icon-font--medium va-middle icon-twitter-24">
#        </i>
#       </a>
#      </li>
#      <li class="footer__socials-item">
#       <a class="footer__socials-item-link" href="//vk.com/bankiru_club" target="_blank">
#        <i class="icon-font icon-font--medium va-middle icon-vk-24">
#        </i>
#       </a>
#      </li>
#      <li class="footer__socials-item">
#       <a class="footer__socials-item-link" href="//www.youtube.com/user/BankiRu" target="_blank">
#        <i class="icon-font icon-font--medium va-middle icon-youtube-24">
#        </i>
#       </a>
#      </li>
#      <li class="footer__socials-item">
#       <a class="footer__socials-item-link" href="//www.instagram.com/banki_ru" target="_blank">
#        <i class="icon-font icon-font--medium va-middle icon-instagram-24">
#        </i>
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="footer__middle-row">
#     <ul class="footer__info-list">
#      <li class="footer__info-item">
#       <a class="footer__info-item-link" href="/info/about/">
#        О проекте
#       </a>
#      </li>
#      <li class="footer__info-item">
#       <a class="footer__info-item-link" href="/info/advertising/">
#        Реклама
#       </a>
#      </li>
#      <li class="footer__info-item">
#       <a class="footer__info-item-link" href="/info/contacts/">
#        Контакты
#       </a>
#      </li>
#      <li class="footer__info-item">
#       <a class="footer__info-item-link" href="/info/contacts/feedback">
#        Служба поддержки
#       </a>
#      </li>
#      <li class="footer__info-item">
#       <a class="footer__info-item-link" href="/sitemap/">
#        Карта сайта
#       </a>
#      </li>
#     </ul>
#     <ul class="footer__info-list">
#      <li class="footer__info-item">
#       <a class="footer__info-item-link" href="http://bankir.ru/" rel="nofollow" target="_blank">
#        Bankir.ru
#       </a>
#      </li>
#      <li class="footer__info-item">
#       <a class="footer__info-item-link" href="http://finparty.ru/" rel="nofollow" target="_blank">
#        Finparty.ru
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="footer__bottom-row">
#     <div>
#      <div class="footer__copyright">
#       <span>
#        © 2005—2019 ИА «Банки.ру».
#       </span>
#       <span>
#        При использовании материалов гиперссылка на Banki.ru обязательна.
#       </span>
#      </div>
#      <div class="footer__policy">
#       <span class="margin-right-small">
#        Свидетельство на товарный знак № 445945 от 18.10.2011г.
#       </span>
#       <a class="footer__policy-link" href="/rules/">
#        Пользовательское соглашение
#       </a>
#       <a class="footer__policy-link" href="/info/private/">
#        Политика обработки персональных данных
#       </a>
#      </div>
#     </div>
#     <a class="footer__age-link" href="/info/about/#agelimit">
#      <img alt="16+" class="display-block lazy-load" data-src="/static/bundles/Layout2018Bundle/images/footer/16+.f438709726f38d361924d05b55406f1e.svg"/>
#     </a>
#    </div>
#   </footer>
#   <div class="footer__counters">
#   </div>
#   <div class="bitrix-component" data-group="banners" data-name="custom:advertising.block" data-params='{"BANNER_TYPE":"FULL_Screen","CODE":"Banner"}' data-template="fullscreen">
#   </div>
#   <div class="bitrix-component" data-group="banners" data-init-inner-modules="1" data-name="custom:advertising.block" data-params='{"BANNER_TYPE":"Bounced","CODE":"Popup"}' data-template="bounced_popup">
#   </div>
#   <div class="layout-footer-fixed-content">
#    <div class="scroll-to-top" id="scrollToTop" title="Наверх">
#     <span class="scroll-to-top__arrow icon-font icon-font--large icon-up-24">
#     </span>
#    </div>
#   </div>
#   <section>
#    <div class="bitrix-component" data-group="banners" data-name="custom:global.poll" data-template="left.bottom">
#    </div>
#   </section>
#   <div class="is-hidden">
#    <div class="bitrix-component" data-group="banners" data-name="custom:advertising.block" data-params='{"BANNER_TYPE":"","CODE":"page_counter"}' data-template="blank">
#    </div>
#    <div class="bitrix-component" data-group="banners" data-name="custom:advertising.block" data-params='{"BANNER_TYPE":"","CODE":"page_counter2"}' data-template="blank">
#    </div>
#   </div>
#   <div class="bitrix-component" data-immediately="true" data-name="ng:statistics">
#   </div>
#   <script src="/static/common/dist/vendor/requirejs/require.js?f0cc8bbb2f">
#   </script>
#   <script src="/static/requirejs-config-ng9c460a603499dbeb09e66b63e8c89797.js">
#   </script>
#   <script src="/static/common/requirejs-config.js?37cc187f7c">
#   </script>
#   <script src="/static/common/dist/common.js?8f0c637f28">
#   </script>
#   <script src="/static/common/dist/bankiru-layout.js?6839248bab">
#   </script>
#   <script>
#    banki.utils.domReady.run();
#   </script>
#   <script>
#    require(['dfp'], function(DFP) {
# 					DFP.default(document, {"allPagesHeader1":{"settings":{"id":"div-gpt-ad-3000000000014-2","path":"\/121239434\/banks_title_tgb1_left\/banks_map_tgb1_left","size":"[\"fluid\"]"},"targets":[{"name":"page_type","value":"inner"},{"name":"placement_type","value":"tgb1_left"}]},"allPagesTopMobile":{"settings":{"id":"div-gpt-ad-1101000000014-0","path":"\/121239434\/banks_title_banner_top_mobile","size":"[\"fluid\"]"},"targets":[{"name":"placement_type","value":"bnr1_mobile"}]},"NotFoundTgbLeft":{"settings":{"id":"div-gpt-ad-4040000000000-1","path":"\/121239434\/404_tgb4_left","size":"[\"fluid\"]"},"targets":[{"name":"page_type","value":"inner"},{"name":"placement_type","value":"tgb4_left"}]},"allPagesBottom":{"settings":{"id":"div-gpt-ad-2000000000014-2","path":"\/121239434\/banks_title_banner_bottom\/banks_map_banner_bottom","size":"[[970,90],[980,150],[728,90],[970,250],[468,60],\"fluid\"]"},"targets":[{"name":"page_type","value":"inner"},{"name":"placement_type","value":"bnr2"}]},"allPagesHeader2":{"settings":{"id":"div-gpt-ad-4000000000014-2","path":"\/121239434\/banks_title_tgb1_right\/banks_map_tgb1_right","size":"[\"fluid\"]"},"targets":[{"name":"page_type","value":"inner"},{"name":"placement_type","value":"tgb1_right"}]},"NotFoundTgbRight":{"settings":{"id":"div-gpt-ad-4040000000000-2","path":"\/121239434\/404_tgb4_right","size":"[\"fluid\"]"},"targets":[{"name":"page_type","value":"inner"},{"name":"placement_type","value":"tgb4_right"}]},"BackgroundBanner":{"settings":{"id":"div-gpt-ad-0000000000000-0","path":"\/121239434\/banks_title_brand_background","size":"[\"fluid\"]"},"targets":[{"name":"placement_type","value":"background"}]},"allPagesTop":{"settings":{"id":"div-gpt-ad-1000000000014-2","path":"\/121239434\/banks_title_banner_top\/banks_map_banner_top","size":"[[970,90],[980,150],[728,90],[468,60],\"fluid\"]"},"targets":[{"name":"page_type","value":"inner"},{"name":"placement_type","value":"bnr1"}]}});
# 				})
#   </script>
#   <script>
#    require(['/static/common/dist/bigdata/big-data.js?938380eddb']);
#   </script>
#   <!-- Rating@Mail.ru counter -->
#   <script type="text/javascript">
#    var _tmr = window._tmr || (window._tmr = []);
#     _tmr.push({id: "892151", type: "pageView", start: (new Date()).getTime()});
#     (function (d, w, id) {
#         if (d.getElementById(id)) return;
#         var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#         ts.src = (d.location.protocol == "https:" ? "https:" : "http:") + "//top-fwz1.mail.ru/js/code.js";
#         var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#         if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#     })(document, window, "topmailru-code");
#   </script>
#   <noscript>
#    <div>
#     <img alt="" src="//top-fwz1.mail.ru/counter?id=892151;js=na" style="border:0;position:absolute;left:-9999px;">
#     </img>
#    </div>
#   </noscript>
#   <!-- //Rating@Mail.ru counter -->
#   <!--LiveInternet counter-->
#   <script type="text/javascript">
#    new Image().src = "//counter.yadro.ru/hit?r"+
# 		escape(document.referrer)+((typeof(screen)=="undefined")?"":
# 			";s"+screen.width+"*"+screen.height+"*"+(screen.colorDepth?
# 			screen.colorDepth:screen.pixelDepth))+";u"+escape(document.URL)+
# 		";"+Math.random();
#   </script>
#   <!--/LiveInternet-->
#   <script type="text/javascript">
#    (window.Image ? (new Image()) : document.createElement('img')).src = location.protocol + '//vk.com/rtrg?r=WgaM98lfd*FgGwsbMiRvKP0u3UZ6PjrmwB*/9v/OOWBErrmWf0LAjZeCZ*frwdYz5k29zp1ipR6CXeHaFSsI2iET3okKWvghZGSFj5bExk8H0g1*eYJq6XFiRvdAmzi6P1eE3afwLHfW2BdUKuDQeOMEJpUJapQ6W5YCgA8LDMw-';
#   </script>
#   <!-- 3941804 -->
#   <noscript>
#    <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1064624868/?value=0&amp;label=5LLBCNThlQQQ5MXT-wM&amp;guid=ON&amp;script=0" width="1"/>
#   </noscript>
#   <!-- Remarketing tags may not be associated with personally identifiable
# information or placed on pages related to sensitive categories. For
# instructions on adding this tag and more information on the above
# requirements, read the setup guide: google.com/ads/remarketingsetup -->
#   <script>
#    var google_conversion_id = 1064624868;
# 	var google_conversion_label = "5LLBCNThlQQQ5MXT-wM";
# 	var google_custom_params = window.google_tag_params;
# 	var google_remarketing_only = true;
#
# 	require(['//www.googleadservices.com/pagead/conversion.js']);
#   </script>
#   <script>
#    require(['//banki.api.useinsider.com/ins.js?id=10001529']);
#   </script>
#   <script>
#    require(['//api.flocktory.com/v2/loader.js?site_id=2251']);
#   </script>
#   <!-- banki.ru ng ui2013 -->
#  </body>
# </html>
# <!-- Page generation time: 0.277 sec. -->

# %%
from selenium import webdriver

import html
from time import sleep

# %%
with webdriver.Firefox() as driver:
    driver.get("https://mail.ru/")
    sleep(3)

# %%
def get_banks_info(driver, url, t_sleep=1):
    driver.get(url)
    sleep(t_sleep)
    
    result = []
    items = driver.find_elements_by_class_name("list__item")
    
    for item in items:
        classes = item.get_attribute('class').split()
        if 'list__item--header' in classes:
            continue
            
        bank_info = {
            'name': item.get_attribute("data-name"),
            'type': item.get_attribute("data-type"),
            'address': item.get_attribute("data-address"),
            'lat': item.get_attribute("data-latitude"),
            'lon': item.get_attribute("data-longitude"),
            'name_bank': item.find_element_by_class_name("item__name__bank").text,
            'access24h': 'круглосуточно' in
                item.find_element_by_class_name("item__schedule").text.lower(),
        }

        if bank_info['lat'] is not None:
            bank_info['lat'] = float(bank_info['lat'])

        if bank_info['lon'] is not None:
            bank_info['lon'] = float(bank_info['lon'])
            
        for f in ['address', 'name', 'name_bank']:
            if bank_info[f] is None:
                continue
            bank_info[f] = html.unescape(bank_info[f])

        result.append(bank_info)
        
    return result


with webdriver.Firefox() as driver:
    result = get_banks_info(driver, url_current)

# %%
result = pd.DataFrame(result)
result.head()
# Out:
#    access24h                                            address        lat  \
# 0      False     Московская обл., г. Люберцы, ул. Красная, д. 4  55.681925
# 1      False                      г. Люберцы, ул. Красная, д. 4  55.681923
# 2      False  Московская обл., г. Люберцы, ул. 3-е Почтовое ...  55.682166
# 3      False  Московская обл., г. Люберцы, ш. Новорязанское,...  55.669862
# 4      False  Московская обл., г. Люберцы, ул. Побратимов, д. 7  55.692013
#
#          lon                             name     name_bank    type
# 0  37.891755                        Отделение  Абсолют Банк  office
# 1  37.891758                         Банкомат  Абсолют Банк     atm
# 2  37.868119  Офис «Авангард-Экспресс» № 8835      Авангард  office
# 3  37.871511  Офис «Авангард-Экспресс» № 8939      Авангард  office
# 4  37.896669  Офис «Авангард-Экспресс» № 8944      Авангард  office

# %% [markdown]
# ### А как можно эту задачу решать по умному?

# %% [markdown]
# Идем в консольку браузера 😉

# %%
offset, limit = 0, 1000

df_banks_coords = []

while True:
    data = {
        'jsonrpc': '2.0',
        'method': 'bankGeo/getObjectsByFilter',
        'params': {
            'offset': offset,
            'limit': limit,
            'type': ['office', 'branch', 'atm', 'cash', 'self_office'],
            'bank_id': ['36119', '325', '63520', '327', '2764', '4389', '3697', '4725'],
        },
        'id': ''
    }
    
    r = requests.post('https://www.banki.ru/api/', json=data)
    if r.status_code != 200:
        raise Exception('Request has failed.')
    
    r = r.json()
    df_banks_coords.extend(r['result']['data'])
    
    if not len(df_banks_coords) < r['result']['total']:
        break
        
    offset += limit
        
df_banks_coords = pd.DataFrame(df_banks_coords)

# %%
df_banks_coords.head()
# Out:
#    active                                            address  bank_id  \
# 0    True                г. Красноярск, ул. Урицкого, д. 117    36119
# 1    True    Тюменская обл., с. Шорохово, ул. Кленовая, д. 8    36119
# 2    True  Республика Марий Эл, п. Медведево, ул. Логинов...    36119
# 3    True                   г. Нижнекамск, ул. Бызова, д. 20    36119
# 4    True              г. Нижнекамск, просп. Вахитова, д. 47    36119
#
#                         icon_url        id  is_main   latitude  longitude  \
# 0  /upload/iblock/8e2/akbars.gif  10754015     True  56.008715  92.864829
# 1  /upload/iblock/8e2/akbars.gif  10756739     True  56.679337  65.391451
# 2  /upload/iblock/8e2/akbars.gif  10754132     True  56.637838  47.816631
# 3  /upload/iblock/8e2/akbars.gif  10755700     True  55.660712  51.828893
# 4  /upload/iblock/8e2/akbars.gif  10755649     True  55.651714  51.821194
#
#        name  region_id  sort type
# 0  Банкомат        657     0  atm
# 1  Банкомат       4174     0  atm
# 2  Банкомат       3293     0  atm
# 3  Банкомат        483     0  atm
# 4  Банкомат        483     0  atm

# %% [markdown]
# ### А что ещё умеет Selenium?

# %%
import random

def random_sleep(offset=1.5, length=4):
    sleep(random.random() * length + offset)

with webdriver.Firefox() as driver:
    driver.get("https://music.yandex.ru/artist/184100")
    random_sleep()
    
    # можно исполнять свой javascript код
    driver.execute_script("window.scrollTo(0, 250);")
    random_sleep(0)
    
    # можно использовать CSS-селекторы или XPath
    # лучше использовать Firefox, он лучше подсказывает пути
    # стоит использовать, если путь выглядит лаконичным
    # пример плохого CSS-селектора
    elem = driver.find_element_by_css_selector(
        'div.d-tabs__tab:nth-child(3) > a:nth-child(1)')
    
    # можно кликать по объектам
    # [ переходим на страничку с альбомами группы ]
    elem.click()
    random_sleep()
    
    # можно искать по классам
    albums = driver.find_element_by_class_name('page-artist__albums').\
        find_elements_by_class_name('album_selectable')
    album = albums[4]
    # [ прокручиваем до нужного альбома ]
    driver.execute_script("return arguments[0].scrollIntoView();", album)
    random_sleep()
    # [ переходим на страничку с выбранным альбомом ]
    album.find_element_by_class_name('d-link').click()
    random_sleep()
    
    driver.execute_script("window.scrollTo(0, 340);")
    random_sleep(0)
    
    # [ кликаем на play ]
    play = driver.find_element_by_class_name('button-play__type_album')
    play.click()
    
    # [ прокликиваем на 5 трек ]
    # пример хорошего CSS-селектора
    next_ = driver.find_element_by_css_selector('.d-icon_track-next')
    for i in range(4):
        next_.click()
        random_sleep(1, 1)
        
    # [ выводим информацию о треке ]
    # пример хорошего CSS-селектора
    elem = driver.find_element_by_css_selector('.track__name')
    artist = elem.find_element_by_class_name('track__artists').text
    title = elem.find_element_by_class_name('track__title').text
    
    tracks = driver.find_element_by_css_selector('.page-album__tracks').\
        find_elements_by_class_name('d-track')
    
    for track_i, track in enumerate(tracks, 1):
        if 'd-track_playing' in track.get_attribute("class").split(' '):
            break
    
    print("Now playing: {} - {}".format(artist, title))
    print("{}th track of {} tracks".format(track_i, len(tracks)))
    
    sleep(15)
# Out:
# Now playing: Three Days Grace - Tell Me Why
# 5th track of 12 tracks

# %% [markdown]
# И многое, многое другое... 😊

# %% [markdown]
# ## Selenium — инструмент тестирования
#
# [Katalon Recorder](https://www.katalon.com/) (Selenium IDE): [Chrome Extension](https://chrome.google.com/webstore/detail/katalon-recorder-selenium/ljdobmomdgdljniojadhoplhkpialdid), [Firefox Extension](https://addons.mozilla.org/en-US/firefox/addon/katalon-automation-record/)
#
# chrome://extensions/
#
# https://mail.ru/ --> "кто такой филантроп?"
